# %% [markdown]
# # Reproduciple Data Analysis

# %%
URL = 'https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD'

from urllib.request import urlretrieve
urlretrieve(URL, 'Fremont_Bridge_Bicycle_Counter.csv')
# Out:
# ('Fremont_Bridge_Bicycle_Counter.csv',
#  <http.client.HTTPMessage at 0x7f30cfc1c370>)

# %%
import pandas as pd
data = pd.read_csv('Fremont_Bridge_Bicycle_Counter.csv', index_col ='Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2022-08-01 00:00:00                  23.0                           7.0
# 2022-08-01 01:00:00                  12.0                           5.0
# 2022-08-01 02:00:00                   3.0                           0.0
# 2022-08-01 03:00:00                   5.0                           2.0
# 2022-08-01 04:00:00                  10.0                           2.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2022-08-01 00:00:00                          16.0
# 2022-08-01 01:00:00                           7.0
# 2022-08-01 02:00:00                           3.0
# 2022-08-01 03:00:00                           3.0
# 2022-08-01 04:00:00                           8.0

# %%
# %matplotlib inline
data.resample('W').sum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

data.columns = ('Total', 'East', 'West')

data.resample('W').sum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#data['Kok'] = data['West'] + data['East']

ax = data.resample('D').sum().rolling(365).sum().plot()
ax.set_ylim(0, None)
# Out:
# (0.0, 1256022.05)

# %%
data.groupby(data.index.time).mean().plot()
# Out:
# <Axes: xlabel='time'>
